# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
class JokeState(TypedDict):
    topic:str
    joke:str
    explanation:str

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI()

# %%
graph=StateGraph(JokeState)

# %%
def Joke_node(state:JokeState):
    prompt=f""" Create a funny joke on this topic = {state['topic']}"""
    joke=model.invoke(prompt).content
    return {'joke':joke}

def Explanation_node(state:JokeState):
    prompt=f""" Explain this joke = {state['joke']} on the topic = {state['topic']}"""
    explanation=model.invoke(prompt).content
    return {'explanation':explanation}

# %%
graph.add_node('Joke_node',Joke_node)
graph.add_node('Explanation_node',Explanation_node)

graph.add_edge(START,'Joke_node')
graph.add_edge('Joke_node','Explanation_node')
graph.add_edge('Explanation_node', END)

checkpointer=InMemorySaver()

workflow=graph.compile(checkpointer=checkpointer)

# %%
config={'configurable':{'thread_id':1}}

config2={'configurable':{'thread_id':2}}
initial_state={'topic':'Shubham'}
final_state=workflow.invoke(initial_state, config=config2)
final_state
# Out:
# {'topic': 'Shubham',
#  'joke': 'Why did Shubham bring a ladder to the bar?\n\nBecause he heard the drinks were on the house!',
#  'explanation': 'This joke plays on the phrase "drinks on the house," which typically means that drinks are complimentary or free. The humor comes from the fact that Shubham took the phrase literally and brought a ladder to the bar, thinking he could actually climb on the roof to get free drinks. It\'s a silly and punny twist on a common expression.'}

# %%
list(workflow.get_state_history(config=config))
# Out:
# [StateSnapshot(values={'topic': 'no 7', 'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!', 'explanation': 'This joke is based on wordplay and the concept of numbers "eating" each other in a playful way. In this case, the number 7 is afraid of 9 because 7 "ate"/"8" (sounds like "eight") 9. The joke plays on the similarity in pronunciation of the words "ate" and "eight" to create a humorous situation where 7 is afraid of being eaten by 9.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4a61-6c40-8002-afe119f230ed'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-22T13:47:02.323083+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4087-686e-8001-4b72e21f05c9'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7', 'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!'}, next=('Explanation_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4087-686e-8001-4b72e21f05c9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-22T13:47:01.289973+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, tasks=(PregelTask(id='c05fd535-e7d4-beea-1ed8-470ddf749c01', name='Explanation_node', path=('__pregel_pull', 'Explanation_node'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is based on wordplay and the concept of numbers "eating" each other in a playful way. In this case, the number 7 is afraid of 9 because 7 "ate"/"8" (sounds like "eight") 9. The joke plays on the similarity in pronunciation of the words "ate" and "eight" to create a humorous situation where 7 is afraid of being eaten by 9.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7'}, next=('Joke_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-22T13:47:00.565569+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-398e-6a76-bfff-50075b62f3cc'}}, tasks=(PregelTask(id='8652a998-e77c-3b18-8831-fd9b06f7d7ad', name='Joke_node', path=('__pregel_pull', 'Joke_node'), error=None, interrupts=(), state=None, result={'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-398e-6a76-bfff-50075b62f3cc'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-22T13:47:00.558881+00:00', parent_config=None, tasks=(PregelTask(id='279d3004-c8ef-f5c2-2b98-f97a98dede33', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'no 7'}),), interrupts=())]

# %%
workflow.update_state( {'configurable':{'thread_id':1,'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999','checkpoint_ns': ''}},{'topic':'Shrinidhi'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f79a0-f707-6748-8001-c1498c96aa15'}}

# %%
{'configurable':{'thread_id':1,'checkpoint_id': '1f0f79a0-f707-6748-8001-c1498c96aa15','checkpoint_ns': ''}})workflow.invoke(None,
# Out:
# {'topic': 'Shrinidhi',
#  'joke': 'Why did Shrinidhi bring a ladder to the bar? \nBecause he heard the drinks were on the house!',
#  'explanation': 'This joke plays on the double meaning of the phrase "on the house." In a bar setting, "on the house" typically means that drinks are being given away for free. However, in this joke, it is interpreted as drinks being literally on top of the structure of the house, leading Shrinidhi to bring a ladder to reach them. This humorous misunderstanding adds a playful twist to the joke.'}

# %%
list(workflow.get_state_history({'thread_id':1}))
# Out:
# [StateSnapshot(values={'topic': 'Shrinidhi', 'joke': 'Why did Shrinidhi bring a ladder to the bar? \nBecause he heard the drinks were on the house!', 'explanation': 'This joke plays on the double meaning of the phrase "on the house." In a bar setting, "on the house" typically means that drinks are being given away for free. However, in this joke, it is interpreted as drinks being literally on top of the structure of the house, leading Shrinidhi to bring a ladder to reach them. This humorous misunderstanding adds a playful twist to the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-f94f-6b96-8003-fcba14728f13'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-22T13:57:38.067301+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-ed95-6cec-8002-fae8c348d37c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Shrinidhi', 'joke': 'Why did Shrinidhi bring a ladder to the bar? \nBecause he heard the drinks were on the house!'}, next=('Explanation_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-ed95-6cec-8002-fae8c348d37c'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-22T13:57:36.837731+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a0-f707-6748-8001-c1498c96aa15'}}, tasks=(PregelTask(id='97e6ce6b-da49-0057-64d7-ae44abe6aee9', name='Explanation_node', path=('__pregel_pull', 'Explanation_node'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the double meaning of the phrase "on the house." In a bar setting, "on the house" typically means that drinks are being given away for free. However, in this joke, it is interpreted as drinks being literally on top of the structure of the house, leading Shrinidhi to bring a ladder to reach them. This humorous misunderstanding adds a playful twist to the joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7', 'joke': 'Why was the number 7 afraid of the number 9?\n\nBecause 7 8 (ate) 9!', 'explanation': 'This joke plays on the homophones "ate" and "eight." In the joke, the number 7 is afraid of the number 9 because "7 8 9," which sounds like "7 ate 9." This is a classic play on words joke that relies on the similar sounds of the word "ate" and the number "eight" for humor.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-3339-61fa-8002-a5f9b0f0475e'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-22T13:57:17.296220+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-2ad8-627c-8001-b93d5e007ebc'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7', 'joke': 'Why was the number 7 afraid of the number 9?\n\nBecause 7 8 (ate) 9!'}, next=('Explanation_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a4-2ad8-627c-8001-b93d5e007ebc'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-22T13:57:16.417656+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, tasks=(PregelTask(id='69e8e291-2f2d-c4b0-b7fe-d9b294250521', name='Explanation_node', path=('__pregel_pull', 'Explanation_node'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the homophones "ate" and "eight." In the joke, the number 7 is afraid of the number 9 because "7 8 9," which sounds like "7 ate 9." This is a classic play on words joke that relies on the similar sounds of the word "ate" and the number "eight" for humor.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Shrinidhi'}, next=('Joke_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f79a0-f707-6748-8001-c1498c96aa15'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-01-22T13:55:50.453826+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, tasks=(PregelTask(id='d8f621ab-c207-30e8-1312-e742b0174a63', name='Joke_node', path=('__pregel_pull', 'Joke_node'), error=None, interrupts=(), state=None, result={'joke': 'Why did Shrinidhi bring a ladder to the bar? \nBecause he heard the drinks were on the house!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7', 'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!', 'explanation': 'This joke is based on wordplay and the concept of numbers "eating" each other in a playful way. In this case, the number 7 is afraid of 9 because 7 "ate"/"8" (sounds like "eight") 9. The joke plays on the similarity in pronunciation of the words "ate" and "eight" to create a humorous situation where 7 is afraid of being eaten by 9.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4a61-6c40-8002-afe119f230ed'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-22T13:47:02.323083+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4087-686e-8001-4b72e21f05c9'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7', 'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!'}, next=('Explanation_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-4087-686e-8001-4b72e21f05c9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-22T13:47:01.289973+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, tasks=(PregelTask(id='c05fd535-e7d4-beea-1ed8-470ddf749c01', name='Explanation_node', path=('__pregel_pull', 'Explanation_node'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is based on wordplay and the concept of numbers "eating" each other in a playful way. In this case, the number 7 is afraid of 9 because 7 "ate"/"8" (sounds like "eight") 9. The joke plays on the similarity in pronunciation of the words "ate" and "eight" to create a humorous situation where 7 is afraid of being eaten by 9.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'no 7'}, next=('Joke_node',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-399e-6ee4-8000-fd2764b5f999'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-22T13:47:00.565569+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-398e-6a76-bfff-50075b62f3cc'}}, tasks=(PregelTask(id='8652a998-e77c-3b18-8831-fd9b06f7d7ad', name='Joke_node', path=('__pregel_pull', 'Joke_node'), error=None, interrupts=(), state=None, result={'joke': 'Why is the number 7 afraid of 9?\n\nBecause 7 8 (ate) 9!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f798d-398e-6a76-bfff-50075b62f3cc'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-22T13:47:00.558881+00:00', parent_config=None, tasks=(PregelTask(id='279d3004-c8ef-f5c2-2b98-f97a98dede33', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'no 7'}),), interrupts=())]
